# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pathlib import Path

workding_dir = str(Path.cwd().parent)
os.chdir(workding_dir)
sys.path.append(workding_dir)
print("workding dir:", workding_dir)
# Out:
# workding dir: /home/inflaton/code/projects/courses/novel-translation

# %%
from dotenv import find_dotenv, load_dotenv

found_dotenv = find_dotenv(".env")

if len(found_dotenv) == 0:
    found_dotenv = find_dotenv(".env.example")
print(f"loading env vars from: {found_dotenv}")
load_dotenv(found_dotenv, override=True)
# Out:
# loading env vars from: /home/inflaton/code/projects/courses/novel-translation/.env
# True

# %%
import os

model_name = os.getenv("MODEL_NAME")
token = os.getenv("HF_TOKEN") or None
load_in_4bit = os.getenv("LOAD_IN_4BIT") == "true"
local_model = os.getenv("LOCAL_MODEL")
hub_model = os.getenv("HUB_MODEL")
num_train_epochs = int(os.getenv("NUM_TRAIN_EPOCHS") or 0)
data_path = os.getenv("DATA_PATH")
results_path = os.getenv("RESULTS_PATH")

max_seq_length = 2048  # Choose any! We auto support RoPE Scaling internally!
dtype = (
    None  # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
)

model_name, load_in_4bit, local_model, hub_model, max_seq_length, num_train_epochs, dtype, data_path, results_path
# Out:
# ('unsloth/Qwen2-0.5B-Instruct-bnb-4bit',
#  True,
#  None,
#  None,
#  2048,
#  1,
#  None,
#  'datasets/mac/mac.tsv',
#  'results/mac-results_v3.csv')

# %%
# !nvidia-smi
# Out:
# Fri Jun 21 00:20:22 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.07              Driver Version: 546.12       CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4080 ...    On  | 00000000:01:00.0  On |                  N/A |
# | N/A   55C    P8               5W / 150W |    975MiB / 12282MiB |     18%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# !./tune-small.sh
# Out:
# Current Directory:
# /home/inflaton/code/projects/courses/novel-translation
# Tuning unsloth/Qwen2-0.5B-Instruct-bnb-4bit
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# loading /home/inflaton/code/projects/courses/novel-translation/translation_engine_v3.py
# [nltk_data] Downloading package wordnet to /home/inflaton/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/inflaton/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/inflaton/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# loading env vars from: /home/inflaton/code/projects/courses/novel-translation/.env
# unsloth/Qwen2-0.5B-Instruct-bnb-4bit True 2048 1 None datasets/mac/mac.tsv results/mac-results_v3.csv True True True
# (1) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 0.0 GB of memory reserved.
# ==((====))==  Unsloth: Fast Qwen2 patching release 2024.6
#    \\   /|    GPU: NVIDIA GeForce RTX 4080 Laptop GPU. Max memory: 11.994 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0. CUDA = 8.9. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# (2) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 0.633 GB of memory reserved.
# loading train/test data files
# DatasetDict({
#     train: Dataset({
#         features: ['chinese', 'english', 'text', 'prompt'],
#         num_rows: 4528
#     })
#     test: Dataset({
#         features: ['chinese', 'english', 'text', 'prompt'],
#         num_rows: 1133
#     })
# })
# Evaluating base model: unsloth/Qwen2-0.5B-Instruct-bnb-4bit
# 100%|███████████████████████████████████████| 1133/1133 [34:28<00:00,  1.83s/it]
#                                              chinese  ...               unsloth/Qwen2-0.5B-Instruct-bnb-4bit
# 0  老耿端起枪，眯缝起一只三角眼，一搂扳机响了枪，冰雹般的金麻雀劈哩啪啦往下落，铁砂子在柳枝间飞...  ...  Old Ge lifted his gun, closing his eyes and sh...
#
# [1 rows x 3 columns]
# (3) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 3.023 GB of memory reserved.
# Unsloth 2024.6 patched 24 layers with 0 QKV layers, 24 O layers and 24 MLP layers.
# (4) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 3.023 GB of memory reserved.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 4,528 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 566
#  "-____-"     Number of trainable parameters = 8,798,208
# {'loss': 1.9412, 'grad_norm': 0.9754176139831543, 'learning_rate': 0.00016613190730837792, 'epoch': 0.18}
# {'loss': 1.779, 'grad_norm': 0.8311804533004761, 'learning_rate': 0.0001304812834224599, 'epoch': 0.35}
# {'loss': 1.7197, 'grad_norm': 0.9739259481430054, 'learning_rate': 9.48306595365419e-05, 'epoch': 0.53}
# {'loss': 1.721, 'grad_norm': 0.8242896795272827, 'learning_rate': 5.918003565062389e-05, 'epoch': 0.71}
# {'loss': 1.6953, 'grad_norm': 0.8749756217002869, 'learning_rate': 2.3529411764705884e-05, 'epoch': 0.88}
# {'train_runtime': 529.5853, 'train_samples_per_second': 8.55, 'train_steps_per_second': 1.069, 'train_loss': 1.7601322942403517, 'epoch': 1.0}
# 100%|█████████████████████████████████████████| 566/566 [08:49<00:00,  1.07it/s]
# (5) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 529.5853 seconds used for training.
# 8.83 minutes used for training.
# Peak reserved memory = 3.023 GB.
# Peak reserved memory for training = 0.0 GB.
# Peak reserved memory % of max memory = 25.204 %.
# Peak reserved memory for training % of max memory = 0.0 %.
# Evaluating fine-tuned model: unsloth/Qwen2-0.5B-Instruct-bnb-4bit
# 100%|███████████████████████████████████████| 1133/1133 [31:58<00:00,  1.69s/it]
#                                              chinese  ...    unsloth/Qwen2-0.5B-Instruct-bnb-4bit(finetuned)
# 0  老耿端起枪，眯缝起一只三角眼，一搂扳机响了枪，冰雹般的金麻雀劈哩啪啦往下落，铁砂子在柳枝间飞...  ...  Old Geng raised his gun and squinted at it wit...
#
# [1 rows x 4 columns]
# (6) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 3.023 GB of memory reserved.
# Unsloth: Merging 4bit and LoRA weights to 4bit...
# This might take 5 minutes...
# Done.
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 10 minutes for Llama-7b... Done.
# Traceback (most recent call last):
#   File "/home/inflaton/code/projects/courses/novel-translation/tune.py", line 135, in <module>
#     save_model(model, tokenizer)
#   File "/home/inflaton/code/projects/courses/novel-translation/translation_engine_v3.py", line 211, in save_model
#     local_model + quantization_method,
# UnboundLocalError: local variable 'quantization_method' referenced before assignment
# Tuning unsloth/Qwen2-1.5B-Instruct-bnb-4bit
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# loading /home/inflaton/code/projects/courses/novel-translation/translation_engine_v3.py
# [nltk_data] Downloading package wordnet to /home/inflaton/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /home/inflaton/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/inflaton/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# loading env vars from: /home/inflaton/code/projects/courses/novel-translation/.env
# unsloth/Qwen2-1.5B-Instruct-bnb-4bit True 2048 1 None datasets/mac/mac.tsv results/mac-results_v3.csv True True True
# (1) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 0.0 GB of memory reserved.
# ==((====))==  Unsloth: Fast Qwen2 patching release 2024.6
#    \\   /|    GPU: NVIDIA GeForce RTX 4080 Laptop GPU. Max memory: 11.994 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0. CUDA = 8.9. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# (2) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 1.516 GB of memory reserved.
# loading train/test data files
# Map: 100%|████████████████████████| 4528/4528 [00:00<00:00, 22748.96 examples/s]
# Map: 100%|████████████████████████| 1133/1133 [00:00<00:00, 16641.38 examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['chinese', 'english', 'text', 'prompt'],
#         num_rows: 4528
#     })
#     test: Dataset({
#         features: ['chinese', 'english', 'text', 'prompt'],
#         num_rows: 1133
#     })
# })
# Evaluating base model: unsloth/Qwen2-1.5B-Instruct-bnb-4bit
# 100%|███████████████████████████████████████| 1133/1133 [54:34<00:00,  2.89s/it]
#                                              chinese  ...              unsloth/Qwen2-1.5B-Instruct-bnb-4bit
# 0  老耿端起枪，眯缝起一只三角眼，一搂扳机响了枪，冰雹般的金麻雀劈哩啪啦往下落，铁砂子在柳枝间飞...  ...  Old耿拿起枪，眯着眼睛，把扳机一扣，子弹像冰雹似的射下来，铁砂子在柳枝间飞溅，发出嚓嚓的声响。
#
# [1 rows x 5 columns]
# (3) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 3.945 GB of memory reserved.
# Unsloth 2024.6 patched 28 layers with 0 QKV layers, 28 O layers and 28 MLP layers.
# Map (num_proc=2): 100%|████████████| 4528/4528 [00:00<00:00, 4707.04 examples/s]
# (4) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 3.945 GB of memory reserved.
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 4,528 | Num Epochs = 1
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 566
#  "-____-"     Number of trainable parameters = 18,464,768
# {'loss': 1.7426, 'grad_norm': 0.6497294306755066, 'learning_rate': 0.00016613190730837792, 'epoch': 0.18}
# {'loss': 1.5704, 'grad_norm': 0.6341724395751953, 'learning_rate': 0.0001304812834224599, 'epoch': 0.35}
# {'loss': 1.5198, 'grad_norm': 0.6494810581207275, 'learning_rate': 9.48306595365419e-05, 'epoch': 0.53}
# {'loss': 1.5214, 'grad_norm': 0.5972827672958374, 'learning_rate': 5.918003565062389e-05, 'epoch': 0.71}
# {'loss': 1.5022, 'grad_norm': 0.5718656182289124, 'learning_rate': 2.3529411764705884e-05, 'epoch': 0.88}
# {'train_runtime': 780.3848, 'train_samples_per_second': 5.802, 'train_steps_per_second': 0.725, 'train_loss': 1.5600922790096, 'epoch': 1.0}
# 100%|█████████████████████████████████████████| 566/566 [13:00<00:00,  1.38s/it]
# (5) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 780.3848 seconds used for training.
# 13.01 minutes used for training.
# Peak reserved memory = 3.945 GB.
# Peak reserved memory for training = 0.0 GB.
# Peak reserved memory % of max memory = 32.891 %.
# Peak reserved memory for training % of max memory = 0.0 %.
# Evaluating fine-tuned model: unsloth/Qwen2-1.5B-Instruct-bnb-4bit
# 100%|█████████████████████████████████████| 1133/1133 [1:09:36<00:00,  3.69s/it]
#                                              chinese  ...    unsloth/Qwen2-1.5B-Instruct-bnb-4bit(finetuned)
# 0  老耿端起枪，眯缝起一只三角眼，一搂扳机响了枪，冰雹般的金麻雀劈哩啪啦往下落，铁砂子在柳枝间飞...  ...  Old Geng lifted his gun and squinted at it thr...
#
# [1 rows x 6 columns]
# (6) GPU = NVIDIA GeForce RTX 4080 Laptop GPU. Max memory = 11.994 GB.
# 5.334 GB of memory reserved.
# Unsloth: Merging 4bit and LoRA weights to 4bit...
# This might take 5 minutes...
# Done.
# Unsloth: Saving tokenizer... Done.
# Unsloth: Saving model... This might take 10 minutes for Llama-7b... Done.
# Traceback (most recent call last):
#   File "/home/inflaton/code/projects/courses/novel-translation/tune.py", line 135, in <module>
#     save_model(model, tokenizer)
#   File "/home/inflaton/code/projects/courses/novel-translation/translation_engine_v3.py", line 211, in save_model
#     local_model + quantization_method,
# UnboundLocalError: local variable 'quantization_method' referenced before assignment

# %%
# !MODEL_NAME=unsloth/Qwen2-0.5B-Instruct-bnb-4bit python eval.py
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# loading /home/inflaton/code/projects/courses/novel-translation/translation_engine_v3.py
# Using the latest cached version of the module from /home/inflaton/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--bleu/9e0985c1200e367cce45605ce0ecb5ede079894e0f24f54613fca08eeb8aff76 (last modified on Wed Oct  4 16:30:25 2023) since it couldn't be found locally at evaluate-metric--bleu, or remotely on the Hugging Face Hub.
# ^C
